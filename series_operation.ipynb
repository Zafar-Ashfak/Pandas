# %% [markdown]
# # Series Operation

# %%
import pandas as pd

# %%
data = pd.read_csv('matches.csv')

# %%
my_series = data['winner'].value_counts()
my_series
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %% [markdown]
# ### Get indices of the data series

# %%
my_series.index
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Gujarat Lions', 'Pune Warriors', 'Rising Pune Supergiant',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='str', name='winner')

# %% [markdown]
# ### Get values of the data series

# %%
my_series.values
# Out:
# array([92, 79, 77, 73, 70, 63, 62, 42, 29, 13, 12, 10,  6,  5])

# %% [markdown]
# ### Get value of the particular index

# %%
print(my_series['Royal Challengers Bangalore'])
# Out:
# 73

# %% [markdown]
#  ### Write an operation to count the total number of matches played by 'Kolkata Knight Riders'

# %%
all_teams = data['team1'].value_counts() + data['team2'].value_counts()

# %%
print(all_team['Kolkata Knight Riders'])
# Out:
# 148
