# %%
import pandas as pd

# %%
df = pd.read_csv('customer_spending_dataset.csv')
df.head(8)
# Out:
#      Name Gender     City Frequency      Item  Spends
# 0  Nitesh      M  Kolkata   Monthly     Pizza      62
# 1     Anu      M  Gurgaon     Never  Sandwich     113
# 2   Mukku      M  Kolkata     Daily     Pizza      64
# 3    Suri      M  Chennai    Weekly     Thali     144
# 4   Rajiv      F    Delhi      Once     Momos      76
# 5   Aarav      M    Patna      Once   Biryani      76
# 6   Priya      M    Delhi   Monthly  Sandwich      28
# 7   Rohan      F  Gurgaon   Monthly   Biryani      72

# %%
df.pivot_table(index='City', columns='Item', values='Spends', aggfunc='mean')
# Out:
# Item       Biryani  Burger   Dosa  Momos     Noodles  Paneer   Pasta  Pizza  \
# City
# Bengaluru      NaN   122.0   44.0  135.0         NaN     NaN   91.75   19.0
# Chennai        NaN     NaN   20.0    NaN         NaN    77.0    7.00    NaN
# Delhi         96.5    35.0   81.0   76.0   52.666667     NaN  131.00    NaN
# Gurgaon       92.5     NaN    NaN   85.0         NaN    34.0   84.00   57.0
# Hyderabad      NaN     NaN   72.0   74.0         NaN     NaN  142.00   70.0
# Jaipur         NaN   115.5  102.0  107.0    9.000000   108.0     NaN   61.0
# Kolkata       73.0     NaN    NaN  116.0  133.000000    50.0     NaN   54.0
# Mumbai         NaN     NaN    NaN   84.0  144.000000     NaN     NaN  117.0
# Patna         76.0     NaN   12.5    NaN   68.000000    98.0  114.00  103.0
# Pune          81.0     NaN   20.0  141.0   59.000000   116.0   38.00    NaN
#
# Item           Samosa    Sandwich  Thali   Vada
# City
# Bengaluru   69.333333   82.500000   80.0    NaN
# ...

# %%
df.pivot_table(index=['City', 'Gender'], columns='Item', values='Spends', aggfunc='mean')
# Out:
# Item              Biryani  Burger   Dosa  Momos  Noodles  Paneer       Pasta  \
# City      Gender
# Bengaluru F           NaN   122.0    NaN  135.0      NaN     NaN  120.000000
#           M           NaN     NaN   44.0    NaN      NaN     NaN   82.333333
# Chennai   F           NaN     NaN   20.0    NaN      NaN     NaN    7.000000
#           M           NaN     NaN    NaN    NaN      NaN    77.0         NaN
# Delhi     F          86.0    54.0   53.0   76.0     59.0     NaN  131.000000
#           M         107.0    16.0  109.0    NaN     40.0     NaN         NaN
# Gurgaon   F          72.0     NaN    NaN   85.0      NaN    34.0   84.000000
#           M         113.0     NaN    NaN    NaN      NaN     NaN         NaN
# Hyderabad F           NaN     NaN    NaN    NaN      NaN     NaN         NaN
#           M           NaN     NaN   72.0   74.0      NaN     NaN  142.000000
# Jaipur    F           NaN   146.0  102.0  107.0      NaN     NaN         NaN
# ...

# %%
df.pivot_table(index=['City', 'Gender'], columns=['Item', 'Frequency'], values='Spends', aggfunc='mean')
# Out:
# Item             Biryani                Burger                 Dosa        \
# Frequency          Daily Monthly   Once  Daily  Never Weekly  Daily Never
# City      Gender
# Bengaluru F          NaN     NaN    NaN  122.0    NaN    NaN    NaN   NaN
#           M          NaN     NaN    NaN    NaN    NaN    NaN    NaN  44.0
# Chennai   F          NaN     NaN    NaN    NaN    NaN    NaN    NaN   NaN
#           M          NaN     NaN    NaN    NaN    NaN    NaN    NaN   NaN
# Delhi     F          NaN    86.0    NaN    NaN    NaN   54.0    NaN   NaN
#           M        107.0     NaN    NaN    NaN    NaN   16.0  109.0   NaN
# Gurgaon   F          NaN    72.0    NaN    NaN    NaN    NaN    NaN   NaN
#           M          NaN     NaN  113.0    NaN    NaN    NaN    NaN   NaN
# Hyderabad F          NaN     NaN    NaN    NaN    NaN    NaN    NaN   NaN
#           M          NaN     NaN    NaN    NaN    NaN    NaN   72.0   NaN
# ...
