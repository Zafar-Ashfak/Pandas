# %% [markdown]
# # Graph plotting

# %%
import pandas as pd

# %%
data = pd.read_csv('matches.csv')

# %% [markdown]
# ### Bar graph of winner team

# %%
data['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %% [markdown]
# ### Vertical Bar graph of top 3 winning team

# %%
data['winner'].value_counts().head(3).plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %% [markdown]
# ### Horizontal bar graph of top 5 winning team

# %%
data['winner'].value_counts().head().plot(kind='barh')
# Out:
# <Axes: ylabel='winner'>

# %% [markdown]
# ### Plotting Pie chart on toss decision

# %%
total_matches = data['toss_decision'].shape[0]
print(f"Total matches: {total_matches}")

field = data['toss_decision'] == 'field'
print(f"Decision to field after winning the toss: {data[field].shape[0]}")

bat = data['toss_decision'] == 'bat'
print(f"Decision to bat after winning the toss: {data[bat].shape[0]}")

data['toss_decision'].value_counts().plot(kind='pie')
# Out:
# Total matches: 636
# Decision to field after winning the toss: 363
# Decision to bat after winning the toss: 273
# <Axes: >

# %% [markdown]
# ### Plotting histogram on win by runs

# %%
data['win_by_runs'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
