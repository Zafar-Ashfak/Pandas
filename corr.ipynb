# %%
import pandas as pd
import seaborn as sbn

# %%
# Sample dataset
data = {
    'Hours_Studied': [10, 8, 3, 1, 7],
    'Test_Score': [95, 85, 60, 45, 80],
    'Screen_Time': [1, 2, 6, 7, 3]
}

df = pd.DataFrame(data)
df
# Out:
#    Hours_Studied  Test_Score  Screen_Time
# 0             10          95            1
# 1              8          85            2
# 2              3          60            6
# 3              1          45            7
# 4              7          80            3

# %%
cr = df.corr()

# %%
sbn.heatmap(cr)
# Out:
# <Axes: >
